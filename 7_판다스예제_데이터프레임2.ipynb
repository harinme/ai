# %% [markdown]
# <a href="https://colab.research.google.com/github/harinme/ai/blob/main/7_%ED%8C%90%EB%8B%A4%EC%8A%A4%EC%98%88%EC%A0%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%842.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 데이터 프레임
#   - 2차원

# %%
import pandas as pd

# %%
list1 = list([['한빛', '남자', '20', '180'],
       ['한결', '남자', '21', '177'],
       ['한라', '여자', '20', '160']])

col_names=['이름','성별','나이','키']
df1=pd.DataFrame(list1,columns=col_names)
df1

df2=pd.DataFrame(list1, index=['1반','2반','3반'], columns=col_names)
df2
df2.index
df2.values
# Out:
# array([['한빛', '남자', '20', '180'],
#        ['한결', '남자', '21', '177'],
#        ['한라', '여자', '20', '160']], dtype=object)

# %%
# 데이터프레임 생성하기 - 방법1 리스트로
dict1 = { '이름': {0:'한빛', 1:'한결', 2:'한라'},
              '성별' :{0:'남자', 1:'남자', 2:'여자'},
             '나이':{0:'20', 1:'21', 2:'20'},
             '키':{0:'180', 1:'177', 2:'160'}}
df2=pd.DataFrame(dict1)
df2
# Out:
#    이름  성별  나이    키
# 0  한빛  남자  20  180
# 1  한결  남자  21  177
# 2  한라  여자  20  160

# %%
# 고고림까지 딕셔너리로 만들어 데터 프레임 생성하기
dic2 ={ '이름':{0:'허준호', 1:'이가원', 2:'배규민',3:'고고림'},
            '성별': {0:'남자',1:'여자',2:'남자',3:'여자'},
            '나이':{0:'30', 1:'24', 2:'23', 3:'21'},
          '키':{0:'183',1:'162',2:'179',3:'182'}
              }
df3=pd.DataFrame(dic2)
df3
df3.to_csv('df3.csv', header=True, index=False, encoding='cp949')
df3.to_excel('df3.xlsx', header=True, index=False, encoding='cp949')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
# 내부 df3.csv 파일 불러오기
# df4=pd.read_csv('df3.csv', sep=',', encoding='cp949')

# 외부 iris.csv 파일 불러오기
# 방법1) 다운 받아서 코랩에 올려주기
# 파일 업로드 하기
# from google.colab import files
# f= files.upload()
iris_df=pd.read_csv('iris.csv', sep=',', encoding='cp949')
iris_df

# 방법2) 다운 받을 url 주소를 써주면 코랩에서 찾아서 올려줌
iris_url='https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'
# Raw의 주소를 써 넣어주기
iris_df=pd.read_csv(iris_url)
iris_df

# vgsales.csv 파일을 찾아서 넣기
vg_url='https://raw.githubusercontent.com/raghav-19/Video-Games-Sales-Data-Analysis/master/vgsales.csv'
vgsales_df=pd.read_csv(vg_url)
vgsales_df
# Out:
#                                Name Platform    Year     Genre  \
# 0                           Kaboom!     2600  1980.0      Misc
# 1                            Boxing     2600  1980.0  Fighting
# 2                        Ice Hockey     2600  1980.0    Sports
# 3                           Freeway     2600  1980.0    Action
# 4                            Bridge     2600  1980.0      Misc
# ...                             ...      ...     ...       ...
# 16534  LEGO Harry Potter: Years 5-7       PC     NaN    Action
# 16535                Happy Feet Two       DS     NaN    Action
# 16536                Happy Feet Two      PS3     NaN    Action
# 16537                Happy Feet Two     X360     NaN    Action
# 16538                Happy Feet Two      Wii     NaN    Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0                                  Activision      1.07      0.07       0.0
# ...
